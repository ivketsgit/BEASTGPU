# %%
import matplotlib.pyplot as plt
import numpy as np
size_plot = 24 * 1.5

from utils import *

# %%
partial_store_threads, partial_store_mem = get_pStore_data()
print(partial_store_mem)

average_total_times, average_worst_times, average_total_std, average_worst_2_std = calculate_avg_and_worst_times("pStore_mem", "time_mem", partial_store_mem)
# server_median, server_min, server_max, server_std = load_cpu_stats_from_files_pînned("other/pinned_server", system_matrix_size)

memory_also_used = (5898240000 + 30105600) / (2**30)


partial_store_mem = (partial_store_mem - memory_also_used) * 1.073741824 # in GB
print(partial_store_mem)

print(average_total_times)
print(average_worst_times)
# Out:
# [ 6 12 18 24 30]
# [ 0.51410534  6.95655629 13.39900723 19.84145818 26.28390912]
# [72.92649341 70.6021419  66.35371318 66.84336637 68.07975415]
# [73.8499539  71.19977755 66.89798096 69.09799026 70.80141925]

# %%
fig, ax = plt.subplots(figsize=(10, 6))

# Plot CPU with error bars
ax.errorbar(
    partial_store_mem, average_total_times, yerr=average_total_std,
    marker='o', label='average', color='blue', capsize=5, linestyle='-'
)

# Plot GPU with error bars
ax.errorbar(
    partial_store_mem, average_worst_times, yerr=average_worst_2_std,
    marker='o', label='worst', color='orange', capsize=5, linestyle='-'
)

ax.set_xlabel('size of buffer (GB)', fontsize=size_plot)
ax.set_ylabel('Execution \nTime (s)', fontsize=size_plot)
# ax.set_title('Execution Time vs threads', fontsize=size_plot)

ax.tick_params(axis='both', labelsize=size_plot)
# ax.set_yscale('log')

fig.canvas.draw()
offset_text = ax.xaxis.get_offset_text()
offset_text.set_size(size_plot)

ax.legend(fontsize=size_plot)
# ax.legend(fontsize=size_plot, loc='upper left', bbox_to_anchor=(0.1, 1))

plt.ylim(bottom=0)
ax.grid(True)
plt.tight_layout()
plt.savefig("graphs/pStore_mem.svg", format='svg')
plt.show()

# %%
partial_store_threads, partial_store_mem = get_pStore_data()
average_total_times, average_worst_times, average_total_std, average_worst_std = calculate_avg_and_worst_times_components("pStore_mem", "time_mem", partial_store_mem)

memory_also_used = (5898240000 + 30105600) / (2**30)


partial_store_mem = (partial_store_mem - memory_also_used) * 1.073741824 # in GB

# %%
fig, ax = plt.subplots(figsize=(10, 6))

# Plot CPU with error bars
ax.errorbar(
    partial_store_mem, average_total_times[:, 0], yerr=average_total_std[:, 0],
    marker='o', label='average', color='blue', capsize=5, linestyle='-'
)

# Plot GPU with error bars
ax.errorbar(
    partial_store_mem, average_worst_times[:, 0], yerr=average_worst_std[:, 0],
    marker='o', label='worst', color='orange', capsize=5, linestyle='-'
)

ax.set_xlabel('size of buffer (GB)', fontsize=size_plot)
ax.set_ylabel('Execution \nTime (s)', fontsize=size_plot)
# ax.set_title('Execution Time vs threads', fontsize=size_plot)

ax.tick_params(axis='both', labelsize=size_plot)
# ax.set_yscale('log')

fig.canvas.draw()
offset_text = ax.xaxis.get_offset_text()
offset_text.set_size(size_plot)

ax.legend(fontsize=size_plot)

plt.ylim(bottom=0)
ax.grid(True)
plt.tight_layout()
plt.savefig("graphs/pStore_mem_calculate.svg", format='svg')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))

# Plot CPU with error bars
ax.errorbar(
    partial_store_mem, average_total_times[:, 1], yerr=average_total_std[:, 1],
    marker='o', label='average', color='blue', capsize=5, linestyle='-'
)

# Plot GPU with error bars
ax.errorbar(
    partial_store_mem, average_worst_times[:, 1], yerr=average_worst_std[:, 1],
    marker='o', label='worst', color='orange', capsize=5, linestyle='-'
)

ax.set_xlabel('size of buffer (GB)', fontsize=size_plot)
ax.set_ylabel('Execution \nTime (s)', fontsize=size_plot)
# ax.set_title('Execution Time vs threads', fontsize=size_plot)

ax.tick_params(axis='both', labelsize=size_plot)
# ax.set_yscale('log')

fig.canvas.draw()
offset_text = ax.xaxis.get_offset_text()
offset_text.set_size(size_plot)

ax.legend(fontsize=size_plot)
# ax.legend(fontsize=size_plot, loc='upper left', bbox_to_anchor=(0.1, 1))

plt.ylim(bottom=0)
ax.grid(True)
plt.tight_layout()
plt.savefig("graphs/pStore_mem_transfer.svg", format='svg')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10, 6))

# Plot CPU with error bars
ax.errorbar(
    partial_store_mem, average_total_times[:, 2], yerr=average_total_std[:, 2],
    marker='o', label='average', color='blue', capsize=5, linestyle='-'
)

# Plot GPU with error bars
ax.errorbar(
    partial_store_mem, average_worst_times[:, 2], yerr=average_worst_std[:, 2],
    marker='o', label='worst', color='orange', capsize=5, linestyle='-'
)

ax.set_xlabel('size of buffer (GB)', fontsize=size_plot)
ax.set_ylabel('Execution \nTime (s)', fontsize=size_plot)
# ax.set_title('Execution Time vs threads', fontsize=size_plot)

ax.tick_params(axis='both', labelsize=size_plot)
# ax.set_yscale('log')

fig.canvas.draw()
offset_text = ax.xaxis.get_offset_text()
offset_text.set_size(size_plot)

ax.legend(fontsize=size_plot)

plt.ylim(bottom=0)
ax.grid(True)
plt.tight_layout()
plt.savefig("graphs/pStore_mem_store.svg", format='svg')
plt.show()
